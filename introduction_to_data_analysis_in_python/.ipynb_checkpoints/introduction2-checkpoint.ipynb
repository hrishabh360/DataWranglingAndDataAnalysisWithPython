# %%
import pandas as pd
from pandas import DataFrame
test = DataFrame([1,2,3], [5,6,6])
test
# Out:
#    0
# 5  1
# 6  2
# 6  3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
fig, ax = plt.subplots()
ax.plot(t,s)
plt.show(fig)

# %%
a = 5
b = 10
print(a+b)
# Out:
# 15

# %% [markdown]
# # Header
#
#  **bold** || _italics_ || `code block #### `
